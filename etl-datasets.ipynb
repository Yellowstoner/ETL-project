# %% [markdown]
# # ETL Project

# %% [markdown]
# Weston Eckloff

# %% [raw]
# AIRPORT DATASET

# %%
import os
import csv
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
airports_csv = os.path.join("Data", "airports.csv")
airports_df = pd.read_csv(airports_csv)
airports_df.head()
# Out:
#   IATA                              AIRPORT           CITY STATE COUNTRY  \
# 0  ABQ            Albuquerque International    Albuquerque    NM     USA
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK     USA
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA     USA
# 3  AUS       Austin-Bergstrom International         Austin    TX     USA
# 4  BDL                Bradley International  Windsor Locks    CT     USA
#
#     LATITUDE   LONGITUDE
# 0  35.040222 -106.609194
# 1  61.174320 -149.996186
# 2  33.640444  -84.426944
# 3  30.194533  -97.669872
# 4  41.938874  -72.683228

# %%
del airports_df['COUNTRY']
del airports_df['LATITUDE']
del airports_df['LONGITUDE']
airports_df.head()
# Out:
#   IATA                              AIRPORT           CITY STATE
# 0  ABQ            Albuquerque International    Albuquerque    NM
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA
# 3  AUS       Austin-Bergstrom International         Austin    TX
# 4  BDL                Bradley International  Windsor Locks    CT

# %%
airports_unique = airports_df['AIRPORT'].unique()
print(len(airports_unique))
print(airports_unique)
# Out:
# 341
# ['Albuquerque International' 'Ted Stevens Anchorage International'
#  'William B Hartsfield-Atlanta Intl' 'Austin-Bergstrom International'
#  'Bradley International' 'Birmingham International'
#  'Nashville International' 'Gen Edw L Logan Intl' 'Buffalo Niagara Intl'
#  'Burbank-Glendale-Pasadena' 'Baltimore-Washington International'
#  'Charleston AFB International' 'Cleveland-Hopkins Intl'
#  'Charlotte Douglas International' 'Port Columbus Intl'
#  'Cincinnati Northern Kentucky Intl' 'Dallas Love '
#  'Ronald Reagan Washington National' 'Denver Intl'
#  'Dallas-Fort Worth International' 'Detroit Metropolitan-Wayne County'
#  'El Paso International' 'Newark Intl' "Fort Lauderdale-Hollywood Int'l"
#  'Honolulu International' 'William P X' 'Washington Dulles International'
#  'George Bush Intercontinental' 'Indianapolis International'
#  'Jacksonville International' 'John F Kennedy Intl'
#  'McCarran International' 'Los Angeles International' 'LaGuardia' 'Adams '
# ...

# %% [raw]
# AIRLINE DELAY DATASET

# %%
delay_csv = os.path.join("Data", "airline_delay_causes.csv")
delay_df = pd.read_csv(delay_csv)
del delay_df['Unnamed: 21']
delay_df.head()
# Out:
#    year   month carrier          carrier_name airport  \
# 0  2004       1      DL  Delta Air Lines Inc.     PBI
# 1  2004       1      DL  Delta Air Lines Inc.     PDX
# 2  2004       1      DL  Delta Air Lines Inc.     PHL
# 3  2004       1      DL  Delta Air Lines Inc.     PHX
# 4  2004       1      DL  Delta Air Lines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...        650.0      126.0
# 1               Portland, OR: Portland International        314.0       61.0
# 2       Philadelphia, PA: Philadelphia International        513.0       97.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International        334.0       78.0
# 4           Pittsburgh, PA: Pittsburgh International        217.0       47.0
#
#    carrier_ct   weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       21.06         6.44  ...          1.0             45.92            4.0
# ...

# %%
delay_filtered = delay_df[(delay_df.year == 2019)]
delay_filtered['City'], delay_filtered['State'] = delay_filtered['airport_name'].str.rsplit(', ').str

delayed_filtered.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c5ccc874767a> in <module>
#       2 delay_filtered['City'], delay_filtered['State'] = delay_filtered['airport_name'].str.rsplit(', ').str
#       3
# ----> 4 delayed_filtered.head()
#
# NameError: name 'delayed_filtered' is not defined

# %% [raw]
# ENPLANEMENT DATASET

# %%
enplanement_csv = os.path.join("Data", "2019-enplanements.csv")
enplanement_df = pd.read_csv(enplanement_csv)
enplanement_df.head()
# Out:
#     Rank  RO  ST Locid       City                         Airport Name S/L  \
# 0   58.0  AL  AK   ANC  Anchorage  Ted Stevens Anchorage International   P
# 1  124.0  AL  AK   FAI  Fairbanks              Fairbanks International   P
# 2  146.0  AL  AK   JNU     Juneau                 Juneau International   P
# 3  204.0  AL  AK   BET     Bethel                               Bethel   P
# 4  215.0  AL  AK   KTN  Ketchikan              Ketchikan International   P
#
#   Hub CY 19 Enplanements CY 18 Enplanements % Change
# 0   M          2,713,843          2,642,607    2.70%
# 1   S            562,420            549,289    2.39%
# 2   N            401,917            440,277   -8.71%
# 3   N            160,874            160,110    0.48%
# 4   N            137,090            135,389    1.26%

# %% [markdown]
# #
